# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

#LANGSMITH TRACKING

os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="o1-mini")

# %%
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x117fce0f0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x130200440> root_client=<openai.OpenAI object at 0x117e63590> root_async_client=<openai.AsyncOpenAI object at 0x117fce150> model_name='o1-mini' temperature=1.0 model_kwargs={} openai_api_key=SecretStr('**********')

# %%
result = llm.invoke("What is Agentic AI")

# %%
print(result)
# Out:
# content='**Agentic AI** refers to artificial intelligence systems designed with a degree of autonomy and the capacity to perform actions independently to achieve specific goals. The term "agency" in this context implies that the AI can make decisions, adapt to changes in its environment, and execute tasks without constant human intervention. Here’s a comprehensive overview of Agentic AI:\n\n### Key Characteristics\n\n1. **Autonomy**: Agentic AI systems operate with a high level of independence, making decisions without needing real-time human input.\n   \n2. **Goal-Oriented Behavior**: These systems are equipped with objectives or goals that guide their actions. They can prioritize tasks to achieve desired outcomes.\n   \n3. **Adaptability and Learning**: Agentic AI can learn from interactions with their environment, allowing them to improve performance over time and adapt to new situations.\n   \n4. **Perception and Interaction**: They can perceive their environment through sensors or data inputs and interact with it effectively to perform tasks.\n\n5. **Decision-Making**: Equipped with algorithms that allow for complex decision-making processes, often involving evaluating multiple factors and potential outcomes.\n\n### Applications\n\n1. **Autonomous Vehicles**: Self-driving cars utilize agentic AI to navigate roads, make real-time driving decisions, and respond to dynamic traffic conditions.\n\n2. **Robotics**: Service robots in manufacturing, healthcare, or domestic environments operate autonomously to perform tasks like assembly, surgery assistance, or household chores.\n\n3. **Virtual Assistants**: Advanced virtual assistants go beyond simple command responses by proactively managing schedules, anticipating user needs, and integrating with various services.\n\n4. **Finance**: Algorithmic trading systems autonomously execute trades based on market analysis and predefined strategies without human intervention.\n\n5. **Healthcare**: AI-driven diagnostic tools can autonomously analyze medical data, identify patterns, and suggest treatment options.\n\n### Benefits\n\n- **Efficiency**: Automating routine and complex tasks can significantly increase productivity and reduce human error.\n  \n- **Scalability**: Agentic AI systems can manage large-scale operations that would be challenging for humans to handle alone.\n\n- **24/7 Operation**: Unlike humans, these systems can operate continuously without the need for breaks or downtime.\n\n### Challenges and Considerations\n\n1. **Ethical Concerns**: Decisions made by agentic AI can have significant ethical implications, especially in areas like autonomous weapons or surveillance.\n\n2. **Accountability**: Determining responsibility when an AI system makes a mistake or causes harm is complex.\n\n3. **Bias and Fairness**: If the data used to train AI systems contain biases, the AI can perpetuate or even amplify these biases in its autonomous decisions.\n\n4. **Security Risks**: Autonomous systems can be targets for hacking or misuse, leading to unauthorized actions.\n\n5. **Loss of Control**: As AI systems become more autonomous, ensuring that they remain aligned with human values and intentions becomes increasingly important.\n\n### Future Outlook\n\nAgentic AI is poised to play a transformative role across various industries by enabling more sophisticated automation and intelligent decision-making. Ongoing research focuses on enhancing the reliability, safety, and ethical alignment of these systems. Additionally, there is a growing emphasis on establishing regulatory frameworks to govern the deployment and operation of agentic AI to mitigate potential risks.\n\n### Distinction from Other AI Types\n\nWhile all AI systems possess some level of intelligence, **agentic AI** specifically emphasizes autonomy and agency. In contrast:\n\n- **Assistive AI**: Systems designed to support human tasks without necessarily operating independently (e.g., recommendation systems).\n  \n- **Narrow AI ...

# %%
print(result.content)
# Out:
# **Agentic AI** refers to artificial intelligence systems designed with a degree of autonomy and the capacity to perform actions independently to achieve specific goals. The term "agency" in this context implies that the AI can make decisions, adapt to changes in its environment, and execute tasks without constant human intervention. Here’s a comprehensive overview of Agentic AI:
#
# ### Key Characteristics
#
# 1. **Autonomy**: Agentic AI systems operate with a high level of independence, making decisions without needing real-time human input.
#
# 2. **Goal-Oriented Behavior**: These systems are equipped with objectives or goals that guide their actions. They can prioritize tasks to achieve desired outcomes.
#
# 3. **Adaptability and Learning**: Agentic AI can learn from interactions with their environment, allowing them to improve performance over time and adapt to new situations.
#
# 4. **Perception and Interaction**: They can perceive their environment through sensors or data inputs and interact with it effectively to perform tasks.
#
# 5. **Decision-Making**: Equipped with algorithms that allow for complex decision-making processes, often involving evaluating multiple factors and potential outcomes.
#
# ### Applications
#
# 1. **Autonomous Vehicles**: Self-driving cars utilize agentic AI to navigate roads, make real-time driving decisions, and respond to dynamic traffic conditions.
#
# 2. **Robotics**: Service robots in manufacturing, healthcare, or domestic environments operate autonomously to perform tasks like assembly, surgery assistance, or household chores.
#
# 3. **Virtual Assistants**: Advanced virtual assistants go beyond simple command responses by proactively managing schedules, anticipating user needs, and integrating with various services.
#
# 4. **Finance**: Algorithmic trading systems autonomously execute trades based on market analysis and predefined strategies without human intervention.
#
# 5. **Healthcare**: AI-driven diagnostic tools can autonomously analyze medical data, identify patterns, and suggest treatment options.
#
# ### Benefits
#
# - **Efficiency**: Automating routine and complex tasks can significantly increase productivity and reduce human error.
#
# - **Scalability**: Agentic AI systems can manage large-scale operations that would be challenging for humans to handle alone.
#
# - **24/7 Operation**: Unlike humans, these systems can operate continuously without the need for breaks or downtime.
#
# ### Challenges and Considerations
#
# 1. **Ethical Concerns**: Decisions made by agentic AI can have significant ethical implications, especially in areas like autonomous weapons or surveillance.
#
# 2. **Accountability**: Determining responsibility when an AI system makes a mistake or causes harm is complex.
#
# 3. **Bias and Fairness**: If the data used to train AI systems contain biases, the AI can perpetuate or even amplify these biases in its autonomous decisions.
#
# 4. **Security Risks**: Autonomous systems can be targets for hacking or misuse, leading to unauthorized actions.
#
# 5. **Loss of Control**: As AI systems become more autonomous, ensuring that they remain aligned with human values and intentions becomes increasingly important.
#
# ### Future Outlook
#
# Agentic AI is poised to play a transformative role across various industries by enabling more sophisticated automation and intelligent decision-making. Ongoing research focuses on enhancing the reliability, safety, and ethical alignment of these systems. Additionally, there is a growing emphasis on establishing regulatory frameworks to govern the deployment and operation of agentic AI to mitigate potential risks.
#
# ### Distinction from Other AI Types
#
# While all AI systems possess some level of intelligence, **agentic AI** specifically emphasizes autonomy and agency. In contrast:
#
# - **Assistive AI**: Systems designed to support human tasks without necessarily operating independently (e.g., recommendation systems).
#
# - **Narrow AI**: AI focused on specific tasks without generalized understanding or autonomy.
#
# - **General AI**: A theoretical form of AI that possesses generalized cognitive abilities comparable to human intelligence, potentially encompassing agentic capabilities.
#
# ### Conclusion
#
# Agentic AI represents a significant advancement in artificial intelligence, embodying systems that can act autonomously to perform tasks and achieve goals with minimal human oversight. While offering numerous benefits in efficiency and capability, it also raises important ethical, legal, and societal questions that must be thoughtfully addressed to ensure these technologies are developed and deployed responsibly.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answer based on the question"),
        ("user","{input}")

    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
llm=ChatOpenAI(model="gpt-4o")

# %%
chain=prompt|llm 

response=chain.invoke({"input":"Can you tell me about Langsmith"})
print(response)
# Out:
# content='Certainly! LangSmith is a platform designed by LangChain to enhance the capabilities of language models and applications by providing robust testing, evaluation, and debugging tools. It extends the functionality of LangChain by allowing developers to deploy language models as agents, integrate them into applications, and systematically evaluate their performance and reliability.\n\nLangSmith focuses on offering tools that can dig into how language applications interact with inputs, manage outputs, and handle various edge cases—crucial for refining and improving model accuracy. It provides insights and analytics that are essential for understanding model behavior, detecting issues, and iterating on model design and prompts.\n\nOverall, LangSmith is aimed at developers who need to ensure their language model-driven applications are performing as expected and achieving the desired results in production environments.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 153, 'prompt_tokens': 32, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb9dce56a8', 'finish_reason': 'stop', 'logprobs': None} id='run-6806aa3b-e545-444a-b3f4-fa2c5fcec2d3-0' usage_metadata={'input_tokens': 32, 'output_tokens': 153, 'total_tokens': 185, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(response.content)
# Out:
# Certainly! LangSmith is a platform designed by LangChain to enhance the capabilities of language models and applications by providing robust testing, evaluation, and debugging tools. It extends the functionality of LangChain by allowing developers to deploy language models as agents, integrate them into applications, and systematically evaluate their performance and reliability.
#
# LangSmith focuses on offering tools that can dig into how language applications interact with inputs, manage outputs, and handle various edge cases—crucial for refining and improving model accuracy. It provides insights and analytics that are essential for understanding model behavior, detecting issues, and iterating on model design and prompts.
#
# Overall, LangSmith is aimed at developers who need to ensure their language model-driven applications are performing as expected and achieving the desired results in production environments.

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith"})

print(response)
# Out:
# Langsmith is a platform developed by LangChain designed to enhance the development, testing, and monitoring of language model applications. It provides a suite of tools to help developers build more reliable and effective applications using language models. Langsmith offers features for debugging, visualization, and measurement throughout the application's lifecycle.
#
# Key functionalities of Langsmith include:
#
# 1. **Development Support**: Langsmith assists in the construction of applications by providing tools that facilitate the integration of language models into systems and streamline their interactions.
#
# 2. **Testing and Debugging**: It provides robust tools for testing language model applications, allowing developers to identify and debug issues efficiently. This helps ensure that applications are performing as expected before deployment.
#
# 3. **Monitoring and Evaluation**: Once applications are live, Langsmith can monitor their performance continuously. It provides insights and analytics on how language models operate in real-world scenarios, aiding in the evaluation and optimization of these models over time.
#
# 4. **Visualization Tools**: Langsmith includes visualization capabilities to help developers understand how data flows through their applications and how language models make decisions based on inputs.
#
# Overall, Langsmith serves as a comprehensive toolkit for developers looking to build sophisticated applications that leverage the power of language models while maintaining high standards of quality and reliability.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

output_parser = JsonOutputParser()
prompt = PromptTemplate(
    template= "Answer the user query. \n{format_instructions}\n{query}\n ",
    input_variables=["query"],
    partial_variables={"format_instructions": output_parser.get_format_instructions()}
)

# %%
chain=prompt|llm|output_parser

response=chain.invoke({"query":"Can you tell me about Langsmith?"})
print(response)
# Out:
# {'name': 'Langsmith', 'description': 'Langsmith is a platform provided by LangChain that offers advanced evaluation and monitoring capabilities tailored for applications built using language models, such as chatbots and natural language processing applications.', 'features': ['Deeper insights into application performance', 'Streamlined application debugging', 'Support for more efficient and effective model updates', 'Monitoring of language model interactions', 'Evaluation of application-driven interactions'], 'use_case': 'Langsmith is designed to enhance the development and management of applications utilizing language models by offering tools for detailed analytics and efficient debugging.'}

# %% [markdown]
# ###RAG###

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://en.wikipedia.org/wiki/Makaibari_Tea_Estate")
loader
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
document = loader.load()
document
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Makaibari_Tea_Estate', 'title': 'Makaibari Tea Estate - Wikipedia', 'language': 'en'}, page_content='\n\n\n\nMakaibari Tea Estate - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nEtymology\n\n\n\n\n\n\n\n\n2\nHistory\n\n\n\n\n\n\n\n\n3\nCoordinates\n\n\n\n\nToggle Coordinates subsection\n\n\n\n\n\n3.1\nThe garden\n\n\n\n\n\n\n\n\n\n\n4\nAchievements\n\n\n\n\n\n\n\n\n5\nTea tourism\n\n\n\n\n\n\n\n\n6\nSocio-cultural amenities\n\n\n\n\n\n\n\n\n7\nReferences\n\n\n\n\n\n\n\n\n8\nExternal links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\nMakaibari Tea Estate\n\n\n\nAdd languages\n\n\n\n\n\nAdd links\n\n\n\n\n\n\n\n\n\n\n\nArticleTalk\n\n\n\n\n\nEnglish\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nReadEditView history\n\n\n\n\n\n\n\nTools\n\n\n\n\n\nTools\nmove to sidebar\nhide\n\n\n\n\t\tActions\n\t\n\n\nReadEditView history\n\n\n\n\n\n\t\tGeneral\n\t\n\n\nWhat links hereRelated changesUpload filePermanent linkPage informationCite this pageGet shortened URLDownload QR code\n\n\n\n\n\n\t\tPrint/export\n\t\n\n\nDownload as PDFPrintable version\n\n\n\n\n\n\t\tIn other projects\n\t\n\n\nWikidata item\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\nmove to sidebar\nhide\n\n\n\n\n\n\n\n\n\nCoordinates: 26°51′20″N 88°16′04″E\ufeff / \ufeff26.855478°N 88.267652°E\ufeff / 26.855478; 88.267652\n\nFrom Wikipedia, the free encyclopedia\n\n\nTea garden in West Bengal, India\nMakaibari Tea EstateLocationDarjeeling district, West Bengal, IndiaCoordinates26°51′20″N 88°16′04″E\ufeff / \ufeff26.855478°N 88.267652°E\ufeff / 26.855478; 88.267652Area120\xa0ha (300 acres)Elevation600–1,500\xa0m (2,000–4,900\xa0ft)Owned\xa0byLuxmi GroupOpen1859\xa0(1859)\nMakaibari Tea Estate  is a tea garden in the Kurseong CD block in the Kurseong subdivision of the Darjeeling district in the Indian state of West Bengal.\n\n\nEtymology[edit]\nMakaibari literally means \'corn field\'.[1]\n\nHistory[edit]\nMakaibari Tea Estate, founded in 1852, by Captain Samler, an Agent of the Darjeeling Tea Company. Samler sold the plantation to Girish Chandra Banerjee, who ran a commissary and mail services in Kurseong. It is one of the oldest tea gardens in Darjeeling. The tea factory at Makaibari was the first in Darjeeling district, commissioned in 1859 and closed in 1933. It is one of the few tea gardens in Darjeeling owned by an Indian family. Except for a brief ownership under Captain Samler, the garden has been with the Banerjees throughout. (Bipra Das Palchoudhuri\'s Gayabari, Tindharia and Mohurgang Tea Estates and Kamal Halder\'s Kamalpur Tea Estate have been with the family ever since the beginning and unlike other Darjeeling tea gardens it had no British connections.) Since the 1970s, Makaibari was led by the fourth generation planter and researcher, Swaraj Kumar Banerjee.[2][1][3][4]\nThe Luxmi Group acquired Makaibari Tea Estate in 2014. However, Swaraj Kumar Banerjee continued to be Chairman of the company till 2017. The Luxmi group owns 25 tea estates in Assam, Darjeeling, Rwanda and North Bengal. Dipankar Chatterjee, the company chairman, has been a planter for over 40 years.[5]\nIn 2017, Swaraj Kumar Baner ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_spliter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap =200)

documents = text_spliter.split_documents(document)

documents
# Out:
# [Document(metadata={'source': 'https://en.wikipedia.org/wiki/Makaibari_Tea_Estate', 'title': 'Makaibari Tea Estate - Wikipedia', 'language': 'en'}, page_content='Makaibari Tea Estate - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload fileSpecial pages\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nEtymology\n\n\n\n\n\n\n\n\n2\nHistory\n\n\n\n\n\n\n\n\n3\nCoordinates\n\n\n\n\nToggle Coordinates subsection\n\n\n\n\n\n3.1\nThe garden\n\n\n\n\n\n\n\n\n\n\n4\nAchievements\n\n\n\n\n\n\n\n\n5\nTea tourism\n\n\n\n\n\n\n\n\n6\nSocio-cultural amenities\n\n\n\n\n\n\n\n\n7\nReferences\n\n\n\n\n\n\n\n\n8\nExternal links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\
adata={'source': 'https://en.wikipedia.org/wiki/Makaibari_Tea_Estate', 'title': 'Makaibari Tea Estate - Wikipedia', 'language': 'en'}, page_content='Socio-cultural amenities[edit]\nMakaibari Tea Estate employs around 700 workers and 45 staff. All workers working in the garden are permanent. The company does not engage casual labourers for garden or factory activity.[9]\nFoodgrains, umbrellas and shoes are given to the workers free of cost. The management has established primary schools. There is a club, a computer centre and community halls with television sets. A library has also been opened for children of garden workers. There is a garden hospital and a visiting doctor. Workers and their families are entitled to free treatment in the garden hospital.[9]\n\nReferences[edit]\n\n\n^ a b c d e "Magical Mystical Makaibari". Makaibari. Archived from the original on 26 February 2020. Retrieved 28 February 2020.\n\n^ "Rajah Banerjee\'s book instils Makaibari Tea Estate Nostalgia". Thunderbolt Tea, Darjeeling. 2019-02-28. Archived from the original on 2020-11-08. Retrieved 2022-05-02.'), Document(id='c796f8ff-0469-4704-a70a-9b438717e0aa', metadata={'source': 'https://en.wikipedia.org/wiki/Makaibari_Tea_Estate', 'title': 'Makaibari Tea Estate - Wikipedia', 'language': 'en'}, page_content='^ "Makaibari Tea Estate, First Demeter Biodynamic Tea Garden in the world". Thunderbolt Tea, Darjeeling. Archived from the original on 2023-08-01. Retrieved 2022-05-09.\n\n^ "Makibari bags best ever price for first flush tea ar Rs. 19,363 a kg". The Economic Times, 28 April 2017. Archived from the original on 17 July 2021. Retrieved 28 February 2020.\n\n^ a b c "Chapter VII Case Studies" (PDF). pages 176-178: Makaibari Tea Estate. Shodhganga. Retrieved 5 March 2020.')]

# %% [markdown]
# ### RAG

# %%
search_result[0].page_content
# Out:
# 'The Luxmi Group acquired Makaibari Tea Estate in 2014. However, Swaraj Kumar Banerjee continued to be Chairman of the company till 2017. The Luxmi group owns 25 tea estates in Assam, Darjeeling, Rwanda and North Bengal. Dipankar Chatterjee, the company chairman, has been a planter for over 40 years.[5]\nIn 2017, Swaraj Kumar Banerjee finally left Makaibari handing over reigns of the tea estate to Rudra Chatterjee, 30 years his junior.\n[6]\nIn 2018, Swaraj Kumar Banerjee announced that he will gift his 12% shares in the Makaibari Tea and Trading Company, which he retained after he sold majority of his stake to the Kolkata-based Luxmi Group, to the workers.[4]'

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
    """
Answer the following question based only on the provided context:
<context>
{context}
</context>


"""
)

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nAnswer the following question based only on the provided context:\n<context>\n{context}\n</context>\n\n\n'), additional_kwargs={})])
# | ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x0000020BFFC77560>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x0000020BFFD7D1F0>, root_client=<openai.OpenAI object at 0x0000020BFF8247A0>, root_async_client=<openai.AsyncOpenAI object at 0x0000020BFFC76C60>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'))
# | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])

# %%
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain

prompt = ChatPromptTemplate.from_messages(
    [("system", "What are everyone's favorite colors:\n\n{context}")]
)
llm = ChatOpenAI(model="gpt-3.5-turbo",temperature=0)
chain = create_stuff_documents_chain(llm, prompt)

docs = [
    Document(page_content="Jesse loves red but not yellow"),
    Document(page_content = "Jamal loves green but not as much as he loves orange")
]

chain.invoke({"context": docs})
# Out:
# "\n\nJesse's favorite color is red, and Jamal's favorite color is orange."
